# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd

# %%
df = pd.read_csv("combined.csv")

# %% [markdown]
# ### Extract Name and Synonyms of Uniprot IDs

# %%
uids = df['Entry']

# %%
"""
Queries Uniprot database and retrieves protein data.
"""
import urllib.request
from urllib.error import HTTPError
from lxml import etree
import lxml.etree
import lxml.html
import json
import xmlschema
import lxml
import requests
from bs4 import BeautifulSoup
import html

# %%
format = '.xml'
#The URL with the protein.xml at the end
url = 'https://www.uniprot.org/uniprot/'
#Makes a schema out of the XML structure
schema = xmlschema.XMLSchema('https://www.uniprot.org/docs/uniprot.xsd') 

DATA = []
LOG = []
for ID in uids:
    names = []
    #print(ID)
    ID = str(ID)
    data = {"ID":ID,"names":[]}
    
    search_url = url+ID+format   
    
    try:   
        with urllib.request.urlopen(search_url) as r:                     
            #Reads the data from the URL for the particular protein
            raw_data = r.read().strip()

            tree = etree.fromstring(raw_data)                          
            #Makes a tree out of the protein's raw data from UniProt


            entry_dict = schema.to_dict(tree)       
            #Makes a dictionary out of the XML schema. (What's the 'tree' argument?)
            content = entry_dict['entry'][0]        
            #The first entry of the dictionary is assigned a variable. It has the xml structure of the protein info
            names = content['protein']                      
            #The information about the protein and it's other info is displayed here and below
    except:
        print(ID, "not found!")
        
    if names:
        
        #recomended name---------------------------
        try:
            rName = names['recommendedName']['fullName']
            
            if type(rName)==dict:
                try:
                    data['names'].append(rName['$'])
                except:
                    print("$ rname not found!")
            else:
                try: 
                    data['names'].append(rName)
                except:
                    print("$ rname not found!")
        except:
            LOG.append({ID: "no  reco full name"})
        
        try:
            sName = names['recommendedName']['shortName']
            
            if type(sName)==list:
                try:
                    data['names'].append(sName[0]['$'])
                except:
                    for st in sName:
                        data['names'].append(st)
            else:
                try:
                    data['names'].append(sName)
                except:
                    print("$ sname not found!")
        except:
            LOG.append({ID:"no Short Name"})
            
        #EC number ------------------------------------------    
        try:
            ecnum = names['recommendedName']['ecNumber']
            if type(ecnum) == list:
                for et in ecnum:
                    try:
                        data['names'].append("EC " + et['$'])
                    except:
                        data['names'].append("EC " + et)
        except:
            LOG.append({ID:"no EC num"})
            
            
        #alternative names---------------------------------------    
        try:
            aNames_list = names['alternativeName']
        except:
            LOG.append(ID)
            
        if aNames_list:
            for item in aNames_list:
                try:
                    afName = item["fullName"]
                    if type(afName)==dict:
                        try: 
                            data['names'].append(afName['$'])
                        except:
                            print("alt fullname not found")
                    else: 
                        data['names'].append(afName)
                except:
                    LOG.append({ID:"no alt full name"})

                try:
                    asName = item["shortName"]
                    if type(asName)==list:
                        try: 
                            data['names'].append(asName[0]['$'])
                        except:
                            for st in asName:
                                data['names'].append(st)
                    else:
                        data['names'].append(asName)
                except:
                    LOG.append({ID: "no reco short name"})
    DATA.append(data)
    #print(names)
    #print("=========================================")
    #print(data)
    #print("-------------------------------------")

# %%
with open("proteins.json",'w') as f:
    json.dump(DATA,f)

# %%
DATA[0]
# Out:
# {'ID': 'P17302',
#  'names': ['Gap junction alpha-1 protein',
#   'Connexin-43',
#   'Cx43',
#   'Gap junction 43 kDa heart protein']}

# %%
file = open("entities.txt","w")

# %%
for item in DATA:
    name = item["ID"]
    names = item['names']
    for n in names:
        nn = str(n)
        nn = nn.lower()
        nn = nn.replace(" ","_")
        name = name + "|" + nn
        
    file.write(name)   
    file.write("\n")
    print(item)
    print(name)
    print("-------------------------")
# Out:
# {'ID': 'P17302', 'names': ['Gap junction alpha-1 protein', 'Connexin-43', 'Cx43', 'Gap junction 43 kDa heart protein']}
# P17302|gap_junction_alpha-1_protein|connexin-43|cx43|gap_junction_43_kda_heart_protein
# -------------------------
# {'ID': 'Q13936', 'names': ['Voltage-dependent L-type calcium channel subunit alpha-1C', 'Calcium channel, L type, alpha-1 polypeptide, isoform 1, cardiac muscle', 'Voltage-gated calcium channel subunit alpha Cav1.2']}
# Q13936|voltage-dependent_l-type_calcium_channel_subunit_alpha-1c|calcium_channel,_l_type,_alpha-1_polypeptide,_isoform_1,_cardiac_muscle|voltage-gated_calcium_channel_subunit_alpha_cav1.2
# -------------------------
# {'ID': 'O95180', 'names': ['Voltage-dependent T-type calcium channel subunit alpha-1H', 'Low-voltage-activated calcium channel alpha1 3.2 subunit', 'Voltage-gated calcium channel subunit alpha Cav3.2']}
# O95180|voltage-dependent_t-type_calcium_channel_subunit_alpha-1h|low-voltage-activated_calcium_channel_alpha1_3.2_subunit|voltage-gated_calcium_channel_subunit_alpha_cav3.2
# -------------------------
# {'ID': 'Q9NS61', 'names': ['Kv channel-interacting protein 2', 'KChIP2', 'A-type potassium channel modulatory protein 2', 'Cardiac voltage-gated potassium channel modulatory subunit', 'Potassium channel-interacting protein 2']}
# Q9NS61|kv_channel-interacting_protein_2|kchip2|a-type_potassium_channel_modulatory_protein_2|cardiac_voltage-gated_potassium_channel_modulatory_subunit|potassium_channel-interacting_protein_2
# -------------------------
# {'ID': 'Q8TD43', 'names': ['Transient receptor potential cation channel subfamily M member 4', 'hTRPM4', 'Calcium-activated non-selective cation channel 1', 'Long transient receptor potential channel 4', 'LTrpC-4', 'LTrpC4', 'Melastatin-4']}
# Q8TD43|transient_receptor_potential_cation_channel_subfamily_m_member_4|htrpm4|calcium-activated_non-selective_cation_channel_1|long_transient_receptor_potential_channel_4|ltrpc-4|ltrpc4|melastatin-4
# -------------------------
# {'ID': 'Q08289', 'names': ['Voltage-dependent L-type calcium channel subunit beta-2', 'CAB2', 'Calcium channel voltage-dependent subunit beta 2', 'Lambert-Eaton myasthenic syndrome antigen B', 'MYSB']}
# Q08289|voltage-dependent_l-type_calcium_channel_subunit_beta-2|cab2|calcium_channel_voltage-dependent_subunit_beta_2|lambert-eaton_myasthenic_syndrome_antigen_b|mysb
# -------------------------
# {'ID': 'Q14524', 'names': ['Sodium channel protein type 5 subunit alpha', 'Sodium channel protein cardiac muscle subunit alpha', 'Sodium channel protein type V subunit alpha', 'Voltage-gated sodium channel subunit alpha Nav1.5', 'hH1']}
# Q14524|sodium_channel_protein_type_5_subunit_alpha|sodium_channel_protein_cardiac_muscle_subunit_alpha|sodium_channel_protein_type_v_subunit_alpha|voltage-gated_sodium_channel_subunit_alpha_nav1.5|hh1
# -------------------------
# {'ID': 'O43497', 'names': ['Voltage-dependent T-type calcium channel subunit alpha-1G', 'Cav3.1c', 'NBR13', 'Voltage-gated calcium channel subunit alpha Cav3.1']}
# O43497|voltage-dependent_t-type_calcium_channel_subunit_alpha-1g|cav3.1c|nbr13|voltage-gated_calcium_channel_subunit_alpha_cav3.1
# -------------------------
# {'ID': 'O00555', 'names': ['Voltage-dependent P/Q-type calcium channel subunit alpha-1A', 'Brain calcium channel I', 'BI', 'Calcium channel, L type, alpha-1 polypeptide isoform 4', 'Voltage-gated calcium channel subunit alpha Cav2.1']}
# O00555|voltage-dependent_p/q-type_calcium_channel_subunit_alpha-1a|brain_calcium_channel_i|bi|calcium_channel,_l_type,_alpha-1_polypeptide_isoform_4|voltage-gated_calcium_channel_subunit_alpha_cav2.1
# -------------------------
# {'ID': 'Q02641', 'names': ['Voltage-dependent L-type calcium channel subunit beta-1', 'CAB1', 'Calcium channel voltage-dependent subunit beta 1']}
# Q02641|voltage-dependent_l-type_calcium_channel_subunit_beta-1|cab1|calcium_channel_voltage-dependent_subunit_beta_1
# -------------------------
# {'ID': 'Q12791', 'names': ['Calcium-activated potassium channel subunit alpha-1', 'BK channel', 'BKCA alpha', 'Calcium-activated potassium channel, subfamily M subunit alpha-1', 'K(VCA)alpha', 'KCa1.1', 'Maxi K channel', 'MaxiK', 'Slo-alpha', 'Slo1', 'Slowpoke homolog', 'Slo homolog', 'hSlo']}
# Q12791|calcium-activated_potassium_channel_subunit_alpha-1|bk_channel|bkca_alpha|calcium-activated_potassium_channel,_subfamily_m_subunit_alpha-1|k(vca)alpha|kca1.1|maxi_k_channel|maxik|slo-alpha|slo1|slowpoke_homolog|slo_homolog|hslo
# -------------------------
# {'ID': 'P54289', 'names': ['Voltage-dependent calcium channel subunit alpha-2/delta-1', 'Voltage-gated calcium channel subunit alpha-2/delta-1']}
# P54289|voltage-dependent_calcium_channel_subunit_alpha-2/delta-1|voltage-gated_calcium_channel_subunit_alpha-2/delta-1
# -------------------------
# {'ID': 'Q01668', 'names': ['Voltage-dependent L-type calcium channel subunit alpha-1D', 'Calcium channel, L type, alpha-1 polypeptide, isoform 2', 'Voltage-gated calcium channel subunit alpha Cav1.3']}
# Q01668|voltage-dependent_l-type_calcium_channel_subunit_alpha-1d|calcium_channel,_l_type,_alpha-1_polypeptide,_isoform_2|voltage-gated_calcium_channel_subunit_alpha_cav1.3
# -------------------------
# {'ID': 'O94759', 'names': ['Transient receptor potential cation channel subfamily M member 2', 'Estrogen-responsive element-associated gene 1 protein', 'Long transient receptor potential channel 2', 'LTrpC-2', {'@evidence': [31], '$': 'LTrpC2'}, 'Transient receptor potential channel 7', 'TrpC7', 'Transient receptor potential melastatin 2']}
# O94759|transient_receptor_potential_cation_channel_subfamily_m_member_2|estrogen-responsive_element-associated_gene_1_protein|long_transient_receptor_potential_channel_2|ltrpc-2|{'@evidence':_[31],_'$':_'ltrpc2'}|transient_receptor_potential_channel_7|trpc7|transient_receptor_potential_melastatin_2
# -------------------------
# {'ID': 'Q9NY47', 'names': ['Voltage-dependent calcium channel subunit alpha-2/delta-2', 'Voltage-gated calcium channel subunit alpha-2/delta-2']}
# Q9NY47|voltage-dependent_calcium_channel_subunit_alpha-2/delta-2|voltage-gated_calcium_channel_subunit_alpha-2/delta-2
# -------------------------
# {'ID': 'P22460', 'names': ['Potassium voltage-gated channel subfamily A member 5', 'HPCN1', 'Voltage-gated potassium channel HK2', 'Voltage-gated potassium channel subunit Kv1.5']}
# P22460|potassium_voltage-gated_channel_subfamily_a_member_5|hpcn1|voltage-gated_potassium_channel_hk2|voltage-gated_potassium_channel_subunit_kv1.5
# -------------------------
# {'ID': 'O14649', 'names': ['Potassium channel subfamily K member 3', 'Acid-sensitive potassium channel protein TASK-1', 'TWIK-related acid-sensitive K(+) channel 1', 'Two pore potassium channel KT3.1', 'Two pore K(+) channel KT3.1']}
# O14649|potassium_channel_subfamily_k_member_3|acid-sensitive_potassium_channel_protein_task-1|twik-related_acid-sensitive_k(+)_channel_1|two_pore_potassium_channel_kt3.1|two_pore_k(+)_channel_kt3.1
# -------------------------
# {'ID': 'Q92736', 'names': ['Ryanodine receptor 2', 'RYR-2', 'RyR2', 'hRYR-2', 'Cardiac muscle ryanodine receptor', 'Cardiac muscle ryanodine receptor-calcium release channel', 'Type 2 ryanodine receptor']}
# Q92736|ryanodine_receptor_2|ryr-2|ryr2|hryr-2|cardiac_muscle_ryanodine_receptor|cardiac_muscle_ryanodine_receptor-calcium_release_channel|type_2_ryanodine_receptor
# -------------------------
# {'ID': 'Q14721', 'names': ['Potassium voltage-gated channel subfamily B member 1', 'Delayed rectifier potassium channel 1', 'DRK1', 'Voltage-gated potassium channel subunit Kv2.1']}
# Q14721|potassium_voltage-gated_channel_subfamily_b_member_1|delayed_rectifier_potassium_channel_1|drk1|voltage-gated_potassium_channel_subunit_kv2.1
# -------------------------
# {'ID': 'P62955', 'names': ['Voltage-dependent calcium channel gamma-7 subunit', 'Neuronal voltage-gated calcium channel gamma-7 subunit', 'Transmembrane AMPAR regulatory protein gamma-7', 'TARP gamma-7']}
# P62955|voltage-dependent_calcium_channel_gamma-7_subunit|neuronal_voltage-gated_calcium_channel_gamma-7_subunit|transmembrane_ampar_regulatory_protein_gamma-7|tarp_gamma-7
# -------------------------
# {'ID': 'Q8WXS5', 'names': ['Voltage-dependent calcium channel gamma-8 subunit', 'Neuronal voltage-gated calcium channel gamma-8 subunit', 'Transmembrane AMPAR regulatory protein gamma-8', 'TARP gamma-8']}
# Q8WXS5|voltage-dependent_calcium_channel_gamma-8_subunit|neuronal_voltage-gated_calcium_channel_gamma-8_subunit|transmembrane_ampar_regulatory_protein_gamma-8|tarp_gamma-8
# -------------------------
# {'ID': 'Q9UBN1', 'names': ['Voltage-dependent calcium channel gamma-4 subunit', 'Neuronal voltage-gated calcium channel gamma-4 subunit', 'Transmembrane AMPAR regulatory protein gamma-4', 'TARP gamma-4']}
# Q9UBN1|voltage-dependent_calcium_channel_gamma-4_subunit|neuronal_voltage-gated_calcium_channel_gamma-4_subunit|transmembrane_ampar_regulatory_protein_gamma-4|tarp_gamma-4
# -------------------------
# {'ID': 'Q9ULQ1', 'names': ['Two pore calcium channel protein 1', 'Voltage-dependent calcium channel protein TPC1']}
# Q9ULQ1|two_pore_calcium_channel_protein_1|voltage-dependent_calcium_channel_protein_tpc1
# -------------------------
# {'ID': 'Q9NPA1', 'names': ['Calcium-activated potassium channel subunit beta-3', 'BK channel subunit beta-3', 'BKbeta3', 'Hbeta3', 'Calcium-activated potassium channel, subfamily M subunit beta-3', 'Charybdotoxin receptor subunit beta-3', 'K(VCA)beta-3', 'Maxi K channel subunit beta-3', 'Slo-beta-3']}
# Q9NPA1|calcium-activated_potassium_channel_subunit_beta-3|bk_channel_subunit_beta-3|bkbeta3|hbeta3|calcium-activated_potassium_channel,_subfamily_m_subunit_beta-3|charybdotoxin_receptor_subunit_beta-3|k(vca)beta-3|maxi_k_channel_subunit_beta-3|slo-beta-3
# -------------------------
# {'ID': 'Q9Y691', 'names': ['Calcium-activated potassium channel subunit beta-2', 'BK channel subunit beta-2', 'BKbeta2', 'Hbeta2', 'Calcium-activated potassium channel, subfamily M subunit beta-2', 'Charybdotoxin receptor subunit beta-2', 'Hbeta3', 'K(VCA)beta-2', 'Maxi K channel subunit beta-2', 'Slo-beta-2']}
# Q9Y691|calcium-activated_potassium_channel_subunit_beta-2|bk_channel_subunit_beta-2|bkbeta2|hbeta2|calcium-activated_potassium_channel,_subfamily_m_subunit_beta-2|charybdotoxin_receptor_subunit_beta-2|hbeta3|k(vca)beta-2|maxi_k_channel_subunit_beta-2|slo-beta-2
# -------------------------
# {'ID': 'Q13563', 'names': ['Polycystin-2', 'PC2', 'Autosomal dominant polycystic kidney disease type II protein', 'Polycystic kidney disease 2 protein', 'Polycystwin', 'R48321', 'Transient receptor potential cation channel subfamily P member 2']}
# Q13563|polycystin-2|pc2|autosomal_dominant_polycystic_kidney_disease_type_ii_protein|polycystic_kidney_disease_2_protein|polycystwin|r48321|transient_receptor_potential_cation_channel_subfamily_p_member_2
# -------------------------
# {'ID': 'Q5R352', 'names': ['Cardiac phospholamban', 'PLB', 'Autosomal dominant polycystic kidney disease type II protein', 'Polycystic kidney disease 2 protein', 'Polycystwin', 'R48321', 'Transient receptor potential cation channel subfamily P member 2']}
# Q5R352|cardiac_phospholamban|plb|autosomal_dominant_polycystic_kidney_disease_type_ii_protein|polycystic_kidney_disease_2_protein|polycystwin|r48321|transient_receptor_potential_cation_channel_subfamily_p_member_2
# -------------------------
# {'ID': 'A0A075B6G3', 'names': ['Autosomal dominant polycystic kidney disease type II protein', 'Polycystic kidney disease 2 protein', 'Polycystwin', 'R48321', 'Transient receptor potential cation channel subfamily P member 2']}
# A0A075B6G3|autosomal_dominant_polycystic_kidney_disease_type_ii_protein|polycystic_kidney_disease_2_protein|polycystwin|r48321|transient_receptor_potential_cation_channel_subfamily_p_member_2
# -------------------------
# {'ID': 'E9PDI6', 'names': ['Voltage-dependent L-type calcium channel subunit alpha', 'Autosomal dominant polycystic kidney disease type II protein', 'Polycystic kidney disease 2 protein', 'Polycystwin', 'R48321', 'Transient receptor potential cation channel subfamily P member 2']}
# E9PDI6|voltage-dependent_l-type_calcium_channel_subunit_alpha|autosomal_dominant_polycystic_kidney_disease_type_ii_protein|polycystic_kidney_disease_2_protein|polycystwin|r48321|transient_receptor_potential_cation_channel_subfamily_p_member_2
# -------------------------
# {'ID': 'F5H522', 'names': ['Voltage-dependent L-type calcium channel subunit alpha', 'Autosomal dominant polycystic kidney disease type II protein', 'Polycystic kidney disease 2 protein', 'Polycystwin', 'R48321', 'Transient receptor potential cation channel subfamily P member 2']}
# F5H522|voltage-dependent_l-type_calcium_channel_subunit_alpha|autosomal_dominant_polycystic_kidney_disease_type_ii_protein|polycystic_kidney_disease_2_protein|polycystwin|r48321|transient_receptor_potential_cation_channel_subfamily_p_member_2
# -------------------------
# {'ID': 'H7BY35', 'names': ['Autosomal dominant polycystic kidney disease type II protein', 'Polycystic kidney disease 2 protein', 'Polycystwin', 'R48321', 'Transient receptor potential cation channel subfamily P member 2']}
# H7BY35|autosomal_dominant_polycystic_kidney_disease_type_ii_protein|polycystic_kidney_disease_2_protein|polycystwin|r48321|transient_receptor_potential_cation_channel_subfamily_p_member_2
# -------------------------
# {'ID': 'A0A087WVX5', 'names': ['Calcium channel voltage-dependent subunit beta 2', 'Voltage-dependent L-type calcium channel subunit beta-2']}
# A0A087WVX5|calcium_channel_voltage-dependent_subunit_beta_2|voltage-dependent_l-type_calcium_channel_subunit_beta-2
# -------------------------
# {'ID': 'Q09MK0', 'names': ['Voltage-dependent L-type calcium channel subunit beta-2']}
# Q09MK0|voltage-dependent_l-type_calcium_channel_subunit_beta-2
# -------------------------
# {'ID': 'Q6TME4', 'names': ['Calcium channel voltage-dependent subunit beta 1', 'Voltage-dependent L-type calcium channel subunit beta-1']}
# Q6TME4|calcium_channel_voltage-dependent_subunit_beta_1|voltage-dependent_l-type_calcium_channel_subunit_beta-1
# -------------------------
# {'ID': 'A0A654IBU3', 'names': ['Connexin-43', 'Gap junction alpha-1 protein']}
# A0A654IBU3|connexin-43|gap_junction_alpha-1_protein
# -------------------------
# {'ID': 'A0A0A0MSA1', 'names': ['Voltage-dependent L-type calcium channel subunit alpha', 'Gap junction alpha-1 protein']}
# A0A0A0MSA1|voltage-dependent_l-type_calcium_channel_subunit_alpha|gap_junction_alpha-1_protein
# -------------------------
# {'ID': 'Q13061', 'names': ['Triadin', 'Gap junction alpha-1 protein']}
# Q13061|triadin|gap_junction_alpha-1_protein
# -------------------------
# {'ID': 'Q9C0H2', 'names': ['Protein tweety homolog 3', 'hTTY3', 'Gap junction alpha-1 protein']}
# Q9C0H2|protein_tweety_homolog_3|htty3|gap_junction_alpha-1_protein
# -------------------------
# {'ID': 'Q9BYP7', 'names': ['Serine/threonine-protein kinase WNK3', 'EC 2.7.11.1', 'Protein kinase lysine-deficient 3', 'Protein kinase with no lysine 3']}
# Q9BYP7|serine/threonine-protein_kinase_wnk3|ec_2.7.11.1|protein_kinase_lysine-deficient_3|protein_kinase_with_no_lysine_3
# -------------------------
# {'ID': 'Q5VVH1', 'names': ['Calcium channel voltage-dependent subunit beta 2', 'Voltage-dependent L-type calcium channel subunit beta-2']}
# Q5VVH1|calcium_channel_voltage-dependent_subunit_beta_2|voltage-dependent_l-type_calcium_channel_subunit_beta-2
# -------------------------
# {'ID': 'A0A024RAF1', 'names': ['Voltage-dependent L-type calcium channel subunit beta-2']}
# A0A024RAF1|voltage-dependent_l-type_calcium_channel_subunit_beta-2
# -------------------------
# {'ID': 'F5H638', 'names': ['Voltage-dependent L-type calcium channel subunit alpha', 'Voltage-dependent L-type calcium channel subunit beta-2']}
# F5H638|voltage-dependent_l-type_calcium_channel_subunit_alpha|voltage-dependent_l-type_calcium_channel_subunit_beta-2
# -------------------------
# {'ID': 'Q6TME0', 'names': ['Calcium channel voltage-dependent subunit beta 2', 'Voltage-dependent L-type calcium channel subunit beta-2']}
# Q6TME0|calcium_channel_voltage-dependent_subunit_beta_2|voltage-dependent_l-type_calcium_channel_subunit_beta-2
# -------------------------
# {'ID': 'F5GY28', 'names': ['Voltage-dependent L-type calcium channel subunit alpha', 'Voltage-dependent L-type calcium channel subunit beta-2']}
# F5GY28|voltage-dependent_l-type_calcium_channel_subunit_alpha|voltage-dependent_l-type_calcium_channel_subunit_beta-2
# -------------------------
# {'ID': 'E7EQ78', 'names': ['Osm-9-like TRP channel 1', 'Transient receptor potential cation channel subfamily V member 1', 'Vanilloid receptor 1']}
# E7EQ78|osm-9-like_trp_channel_1|transient_receptor_potential_cation_channel_subfamily_v_member_1|vanilloid_receptor_1
# -------------------------
# {'ID': 'A0A0A0MR67', 'names': ['Voltage-dependent L-type calcium channel subunit alpha', 'Transient receptor potential cation channel subfamily V member 1', 'Vanilloid receptor 1']}
# A0A0A0MR67|voltage-dependent_l-type_calcium_channel_subunit_alpha|transient_receptor_potential_cation_channel_subfamily_v_member_1|vanilloid_receptor_1
# -------------------------
# {'ID': 'P0DP25', 'names': ['Calmodulin-3', 'Transient receptor potential cation channel subfamily V member 1', 'Vanilloid receptor 1']}
# P0DP25|calmodulin-3|transient_receptor_potential_cation_channel_subfamily_v_member_1|vanilloid_receptor_1
# -------------------------
# {'ID': 'P49810', 'names': ['Presenilin-2', 'PS-2', 'EC 3.4.23.-', 'AD3LP', 'AD5', 'E5-1', 'STM-2']}
# P49810|presenilin-2|ps-2|ec_3.4.23.-|ad3lp|ad5|e5-1|stm-2
# -------------------------
# {'ID': 'Q16623', 'names': ['Syntaxin-1A', 'Neuron-specific antigen HPC-1']}
# Q16623|syntaxin-1a|neuron-specific_antigen_hpc-1
# -------------------------
# {'ID': 'P30626', 'names': ['Sorcin', '22 kDa protein', 'CP-22', 'CP22', 'V19']}
# P30626|sorcin|22_kda_protein|cp-22|cp22|v19
# -------------------------
# {'ID': 'P56373', 'names': ['P2X purinoceptor 3', 'P2X3', 'ATP receptor', 'Purinergic receptor']}
# P56373|p2x_purinoceptor_3|p2x3|atp_receptor|purinergic_receptor
# -------------------------
# {'ID': 'Q08499', 'names': ["cAMP-specific 3',5'-cyclic phosphodiesterase 4D", 'EC 3.1.4.53', 'DPDE3', 'PDE43']}
# Q08499|camp-specific_3',5'-cyclic_phosphodiesterase_4d|ec_3.1.4.53|dpde3|pde43
# -------------------------
# {'ID': 'Q08209', 'names': ['Serine/threonine-protein phosphatase 2B catalytic subunit alpha isoform', 'EC 3.1.3.16', 'CAM-PRP catalytic subunit', 'Calmodulin-dependent calcineurin A subunit alpha isoform']}
# Q08209|serine/threonine-protein_phosphatase_2b_catalytic_subunit_alpha_isoform|ec_3.1.3.16|cam-prp_catalytic_subunit|calmodulin-dependent_calcineurin_a_subunit_alpha_isoform
# -------------------------
# {'ID': 'Q7Z443', 'names': ['Polycystic kidney disease protein 1-like 3', 'PC1-like 3 protein', 'Polycystin-1L3']}
# Q7Z443|polycystic_kidney_disease_protein_1-like_3|pc1-like_3_protein|polycystin-1l3
# -------------------------
# {'ID': 'Q9P0L9', 'names': ['Polycystic kidney disease 2-like 1 protein', 'Polycystin-2 homolog', 'Polycystin-2L1', 'Polycystin-L', 'Polycystin-L1']}
# Q9P0L9|polycystic_kidney_disease_2-like_1_protein|polycystin-2_homolog|polycystin-2l1|polycystin-l|polycystin-l1
# -------------------------
# {'ID': 'Q8NBP7', 'names': ['Proprotein convertase subtilisin/kexin type 9', 'EC 3.4.21.-', 'Neural apoptosis-regulated convertase 1', 'NARC-1', 'Proprotein convertase 9', 'PC9', 'Subtilisin/kexin-like protease PC9']}
# Q8NBP7|proprotein_convertase_subtilisin/kexin_type_9|ec_3.4.21.-|neural_apoptosis-regulated_convertase_1|narc-1|proprotein_convertase_9|pc9|subtilisin/kexin-like_protease_pc9
# -------------------------
# {'ID': 'Q8TDX9', 'names': ['Polycystic kidney disease protein 1-like 1', 'PC1-like 1 protein', 'Polycystin-1L1']}
# Q8TDX9|polycystic_kidney_disease_protein_1-like_1|pc1-like_1_protein|polycystin-1l1
# -------------------------
# {'ID': 'Q9BSA4', 'names': ['Protein tweety homolog 2', 'hTTY2', 'PC1-like 1 protein', 'Polycystin-1L1']}
# Q9BSA4|protein_tweety_homolog_2|htty2|pc1-like_1_protein|polycystin-1l1
# -------------------------
# {'ID': 'P19429', 'names': ['Troponin I, cardiac muscle', 'Cardiac troponin I']}
# P19429|troponin_i,_cardiac_muscle|cardiac_troponin_i
# -------------------------
# {'ID': 'P05556', 'names': ['Integrin beta-1', 'Fibronectin receptor subunit beta', 'Glycoprotein IIa', 'GPIIA', 'VLA-4 subunit beta']}
# P05556|integrin_beta-1|fibronectin_receptor_subunit_beta|glycoprotein_iia|gpiia|vla-4_subunit_beta
# -------------------------
# {'ID': 'P26678', 'names': ['Cardiac phospholamban', 'PLB', 'Fibronectin receptor subunit beta', 'Glycoprotein IIa', 'GPIIA', 'VLA-4 subunit beta']}
# P26678|cardiac_phospholamban|plb|fibronectin_receptor_subunit_beta|glycoprotein_iia|gpiia|vla-4_subunit_beta
# -------------------------
# {'ID': 'Q8IYU8', 'names': ['Calcium uptake protein 2, mitochondrial', 'EF-hand domain-containing family member A1']}
# Q8IYU8|calcium_uptake_protein_2,_mitochondrial|ef-hand_domain-containing_family_member_a1
# -------------------------
# {'ID': 'P56704', 'names': ['Protein Wnt-3a', 'EF-hand domain-containing family member A1']}
# P56704|protein_wnt-3a|ef-hand_domain-containing_family_member_a1
# -------------------------
# {'ID': 'P78417', 'names': ['Glutathione S-transferase omega-1', 'GSTO-1', 'EC 2.5.1.18', 'Glutathione S-transferase omega 1-1', 'GSTO 1-1', 'Glutathione-dependent dehydroascorbate reductase', 'Monomethylarsonic acid reductase', 'MMA(V) reductase', 'S-(Phenacyl)glutathione reductase', 'SPG-R']}
# P78417|glutathione_s-transferase_omega-1|gsto-1|ec_2.5.1.18|glutathione_s-transferase_omega_1-1|gsto_1-1|glutathione-dependent_dehydroascorbate_reductase|monomethylarsonic_acid_reductase|mma(v)_reductase|s-(phenacyl)glutathione_reductase|spg-r
# -------------------------
# {'ID': 'P29475', 'names': ['Nitric oxide synthase, brain', 'EC 1.14.13.39', 'Constitutive NOS', 'NC-NOS', 'NOS type I', 'Neuronal NOS', 'N-NOS', 'nNOS', 'Peptidyl-cysteine S-nitrosylase NOS1', 'bNOS']}
# P29475|nitric_oxide_synthase,_brain|ec_1.14.13.39|constitutive_nos|nc-nos|nos_type_i|neuronal_nos|n-nos|nnos|peptidyl-cysteine_s-nitrosylase_nos1|bnos
# -------------------------
# {'ID': 'P49768', 'names': ['Presenilin-1', 'PS-1', 'EC 3.4.23.-', 'Protein S182']}
# P49768|presenilin-1|ps-1|ec_3.4.23.-|protein_s182
# -------------------------
# {'ID': 'Q86VP3', 'names': ['Phosphofurin acidic cluster sorting protein 2', 'PACS-2', 'PACS1-like protein']}
# Q86VP3|phosphofurin_acidic_cluster_sorting_protein_2|pacs-2|pacs1-like_protein
# -------------------------
# {'ID': 'Q9UKS6', 'names': ['Protein kinase C and casein kinase substrate in neurons protein 3', 'SH3 domain-containing protein 6511']}
# Q9UKS6|protein_kinase_c_and_casein_kinase_substrate_in_neurons_protein_3|sh3_domain-containing_protein_6511
# -------------------------
# {'ID': 'Q14571', 'names': ['Inositol 1,4,5-trisphosphate receptor type 2', 'IP3 receptor isoform 2', 'IP3R 2', 'InsP3R2', 'Type 2 inositol 1,4,5-trisphosphate receptor', 'Type 2 InsP3 receptor']}
# Q14571|inositol_1,4,5-trisphosphate_receptor_type_2|ip3_receptor_isoform_2|ip3r_2|insp3r2|type_2_inositol_1,4,5-trisphosphate_receptor|type_2_insp3_receptor
# -------------------------
# {'ID': 'O60721', 'names': ['Sodium/potassium/calcium exchanger 1', 'Na(+)/K(+)/Ca(2+)-exchange protein 1', 'Retinal rod Na-Ca+K exchanger', 'Solute carrier family 24 member 1']}
# O60721|sodium/potassium/calcium_exchanger_1|na(+)/k(+)/ca(2+)-exchange_protein_1|retinal_rod_na-ca+k_exchanger|solute_carrier_family_24_member_1
# -------------------------
# {'ID': 'Q7Z442', 'names': ['Polycystic kidney disease protein 1-like 2', 'PC1-like 2 protein', 'Polycystin-1L2']}
# Q7Z442|polycystic_kidney_disease_protein_1-like_2|pc1-like_2_protein|polycystin-1l2
# -------------------------
# {'ID': 'P27169', 'names': ['Serum paraoxonase/arylesterase 1', 'PON 1', 'EC 3.1.1.2', 'EC 3.1.1.81', 'EC 3.1.8.1', 'Aromatic esterase 1', 'A-esterase 1', 'K-45', 'Serum aryldialkylphosphatase 1']}
# P27169|serum_paraoxonase/arylesterase_1|pon_1|ec_3.1.1.2|ec_3.1.1.81|ec_3.1.8.1|aromatic_esterase_1|a-esterase_1|k-45|serum_aryldialkylphosphatase_1
# -------------------------
# {'ID': 'P32418', 'names': ['Sodium/calcium exchanger 1', 'Na(+)/Ca(2+)-exchange protein 1', 'Solute carrier family 8 member 1']}
# P32418|sodium/calcium_exchanger_1|na(+)/ca(2+)-exchange_protein_1|solute_carrier_family_8_member_1
# -------------------------
# {'ID': 'P19634', 'names': ['Sodium/hydrogen exchanger 1', 'APNH', 'Na(+)/H(+) antiporter, amiloride-sensitive', 'Na(+)/H(+) exchanger 1', 'NHE-1', 'Solute carrier family 9 member 1']}
# P19634|sodium/hydrogen_exchanger_1|apnh|na(+)/h(+)_antiporter,_amiloride-sensitive|na(+)/h(+)_exchanger_1|nhe-1|solute_carrier_family_9_member_1
# -------------------------
# {'ID': 'Q13424', 'names': ['Alpha-1-syntrophin', '59 kDa dystrophin-associated protein A1 acidic component 1', 'Pro-TGF-alpha cytoplasmic domain-interacting protein 1', 'TACIP1', 'Syntrophin-1']}
# Q13424|alpha-1-syntrophin|59_kda_dystrophin-associated_protein_a1_acidic_component_1|pro-tgf-alpha_cytoplasmic_domain-interacting_protein_1|tacip1|syntrophin-1
# -------------------------
# {'ID': 'P21796', 'names': ['Voltage-dependent anion-selective channel protein 1', 'VDAC-1', 'hVDAC1', 'Outer mitochondrial membrane protein porin 1', 'Plasmalemmal porin', 'Porin 31HL', 'Porin 31HM']}
# P21796|voltage-dependent_anion-selective_channel_protein_1|vdac-1|hvdac1|outer_mitochondrial_membrane_protein_porin_1|plasmalemmal_porin|porin_31hl|porin_31hm
# -------------------------
# {'ID': 'Q9UBN4', 'names': ['Short transient receptor potential channel 4', 'TrpC4', 'Trp-related protein 4', 'hTrp-4', 'hTrp4']}
# Q9UBN4|short_transient_receptor_potential_channel_4|trpc4|trp-related_protein_4|htrp-4|htrp4
# -------------------------
# {'ID': 'P23327', 'names': ['Sarcoplasmic reticulum histidine-rich calcium-binding protein', 'Trp-related protein 4', 'hTrp-4', 'hTrp4']}
# P23327|sarcoplasmic_reticulum_histidine-rich_calcium-binding_protein|trp-related_protein_4|htrp-4|htrp4
# -------------------------
# {'ID': 'P21817', 'names': ['Ryanodine receptor 1', 'RYR-1', 'RyR1', 'Skeletal muscle calcium release channel', 'Skeletal muscle ryanodine receptor', 'Skeletal muscle-type ryanodine receptor', 'Type 1 ryanodine receptor']}
# P21817|ryanodine_receptor_1|ryr-1|ryr1|skeletal_muscle_calcium_release_channel|skeletal_muscle_ryanodine_receptor|skeletal_muscle-type_ryanodine_receptor|type_1_ryanodine_receptor
# -------------------------
# {'ID': 'Q13425', 'names': ['Beta-2-syntrophin', '59 kDa dystrophin-associated protein A1 basic component 2', 'Syntrophin-3', 'SNT3', 'Syntrophin-like', 'SNTL']}
# Q13425|beta-2-syntrophin|59_kda_dystrophin-associated_protein_a1_basic_component_2|syntrophin-3|snt3|syntrophin-like|sntl
# -------------------------
# {'ID': 'Q9NZV5', 'names': ['Selenoprotein N', 'SelN', '59 kDa dystrophin-associated protein A1 basic component 2', 'Syntrophin-3', 'SNT3', 'Syntrophin-like', 'SNTL']}
# Q9NZV5|selenoprotein_n|seln|59_kda_dystrophin-associated_protein_a1_basic_component_2|syntrophin-3|snt3|syntrophin-like|sntl
# -------------------------
# {'ID': 'P01160', 'names': ['Natriuretic peptides A', 'Atrial natriuretic factor prohormone', 'proANF', 'Atrial natriuretic peptide prohormone', 'preproANP', 'Atriopeptigen', 'Cardiodilatin', 'CDD', 'preproCDD-ANF']}
# P01160|natriuretic_peptides_a|atrial_natriuretic_factor_prohormone|proanf|atrial_natriuretic_peptide_prohormone|preproanp|atriopeptigen|cardiodilatin|cdd|preprocdd-anf
# -------------------------
# {'ID': 'Q16611', 'names': ['Bcl-2 homologous antagonist/killer', 'Apoptosis regulator BAK', 'Bcl-2-like protein 7', 'Bcl2-L-7']}
# Q16611|bcl-2_homologous_antagonist/killer|apoptosis_regulator_bak|bcl-2-like_protein_7|bcl2-l-7
# -------------------------
# {'ID': 'Q99653', 'names': ['Calcineurin B homologous protein 1', 'Calcineurin B-like protein', 'Calcium-binding protein CHP', 'Calcium-binding protein p22', 'EF-hand calcium-binding domain-containing protein p22']}
# Q99653|calcineurin_b_homologous_protein_1|calcineurin_b-like_protein|calcium-binding_protein_chp|calcium-binding_protein_p22|ef-hand_calcium-binding_domain-containing_protein_p22
# -------------------------
# {'ID': 'P06241', 'names': ['Tyrosine-protein kinase Fyn', 'EC 2.7.10.2', 'Proto-oncogene Syn', 'Proto-oncogene c-Fyn', 'Src-like kinase', 'SLK', 'p59-Fyn']}
# P06241|tyrosine-protein_kinase_fyn|ec_2.7.10.2|proto-oncogene_syn|proto-oncogene_c-fyn|src-like_kinase|slk|p59-fyn
# -------------------------
# {'ID': 'O00499', 'names': ['Myc box-dependent-interacting protein 1', 'Amphiphysin II', 'Amphiphysin-like protein', 'Box-dependent myc-interacting protein 1', 'Bridging integrator 1']}
# O00499|myc_box-dependent-interacting_protein_1|amphiphysin_ii|amphiphysin-like_protein|box-dependent_myc-interacting_protein_1|bridging_integrator_1
# -------------------------
# {'ID': 'P41180', 'names': ['Extracellular calcium-sensing receptor', 'CaR', 'Parathyroid cell calcium-sensing receptor 1', 'PCaR1']}
# P41180|extracellular_calcium-sensing_receptor|car|parathyroid_cell_calcium-sensing_receptor_1|pcar1
# -------------------------
# {'ID': 'P12814', 'names': ['Alpha-actinin-1', 'Alpha-actinin cytoskeletal isoform', 'F-actin cross-linking protein', 'Non-muscle alpha-actinin-1']}
# P12814|alpha-actinin-1|alpha-actinin_cytoskeletal_isoform|f-actin_cross-linking_protein|non-muscle_alpha-actinin-1
# -------------------------
# {'ID': 'Q9Y696', 'names': ['Chloride intracellular channel protein 4', 'Intracellular chloride ion channel protein p64H1']}
# Q9Y696|chloride_intracellular_channel_protein_4|intracellular_chloride_ion_channel_protein_p64h1
# -------------------------
# {'ID': 'O60610', 'names': ['Protein diaphanous homolog 1', 'Diaphanous-related formin-1', 'DRF1']}
# O60610|protein_diaphanous_homolog_1|diaphanous-related_formin-1|drf1
# -------------------------
# {'ID': 'O43603', 'names': ['Galanin receptor type 2', 'GAL2-R', 'GALR-2', 'Diaphanous-related formin-1', 'DRF1']}
# O43603|galanin_receptor_type_2|gal2-r|galr-2|diaphanous-related_formin-1|drf1
# -------------------------
# {'ID': 'P0DP24', 'names': ['Calmodulin-2', 'Diaphanous-related formin-1', 'DRF1']}
# P0DP24|calmodulin-2|diaphanous-related_formin-1|drf1
# -------------------------
# {'ID': 'P62942', 'names': ['Peptidyl-prolyl cis-trans isomerase FKBP1A', 'PPIase FKBP1A', 'EC 5.2.1.8', '12 kDa FK506-binding protein', '12 kDa FKBP', 'FKBP-12', 'Calstabin-1', 'FK506-binding protein 1A', 'FKBP-1A', 'Immunophilin FKBP12', 'Rotamase']}
# P62942|peptidyl-prolyl_cis-trans_isomerase_fkbp1a|ppiase_fkbp1a|ec_5.2.1.8|12_kda_fk506-binding_protein|12_kda_fkbp|fkbp-12|calstabin-1|fk506-binding_protein_1a|fkbp-1a|immunophilin_fkbp12|rotamase
# -------------------------
# {'ID': 'P17612', 'names': ['cAMP-dependent protein kinase catalytic subunit alpha', 'PKA C-alpha', 'EC 2.7.11.11', '12 kDa FK506-binding protein', '12 kDa FKBP', 'FKBP-12', 'Calstabin-1', 'FK506-binding protein 1A', 'FKBP-1A', 'Immunophilin FKBP12', 'Rotamase']}
# P17612|camp-dependent_protein_kinase_catalytic_subunit_alpha|pka_c-alpha|ec_2.7.11.11|12_kda_fk506-binding_protein|12_kda_fkbp|fkbp-12|calstabin-1|fk506-binding_protein_1a|fkbp-1a|immunophilin_fkbp12|rotamase
# -------------------------
# {'ID': 'P68106', 'names': ['Peptidyl-prolyl cis-trans isomerase FKBP1B', 'PPIase FKBP1B', 'EC 5.2.1.8', '12.6 kDa FK506-binding protein', '12.6 kDa FKBP', 'FKBP-12.6', 'FK506-binding protein 1B', 'FKBP-1B', 'Immunophilin FKBP12.6', 'Rotamase', 'h-FKBP-12']}
# P68106|peptidyl-prolyl_cis-trans_isomerase_fkbp1b|ppiase_fkbp1b|ec_5.2.1.8|12.6_kda_fk506-binding_protein|12.6_kda_fkbp|fkbp-12.6|fk506-binding_protein_1b|fkbp-1b|immunophilin_fkbp12.6|rotamase|h-fkbp-12
# -------------------------
# {'ID': 'P35212', 'names': ['Gap junction alpha-4 protein', 'Connexin-37', 'Cx37']}
# P35212|gap_junction_alpha-4_protein|connexin-37|cx37
# -------------------------
# {'ID': 'O15247', 'names': ['Chloride intracellular channel protein 2', 'XAP121']}
# O15247|chloride_intracellular_channel_protein_2|xap121
# -------------------------
# {'ID': 'P62258', 'names': ['14-3-3 protein epsilon', '14-3-3E', 'XAP121']}
# P62258|14-3-3_protein_epsilon|14-3-3e|xap121
# -------------------------
# {'ID': 'O75052', 'names': ['Carboxyl-terminal PDZ ligand of neuronal nitric oxide synthase protein', 'C-terminal PDZ ligand of neuronal nitric oxide synthase protein', 'Nitric oxide synthase 1 adaptor protein']}
# O75052|carboxyl-terminal_pdz_ligand_of_neuronal_nitric_oxide_synthase_protein|c-terminal_pdz_ligand_of_neuronal_nitric_oxide_synthase_protein|nitric_oxide_synthase_1_adaptor_protein
# -------------------------
# {'ID': 'P11532', 'names': ['Dystrophin', 'C-terminal PDZ ligand of neuronal nitric oxide synthase protein', 'Nitric oxide synthase 1 adaptor protein']}
# P11532|dystrophin|c-terminal_pdz_ligand_of_neuronal_nitric_oxide_synthase_protein|nitric_oxide_synthase_1_adaptor_protein
# -------------------------
# {'ID': 'Q12797', 'names': ['Aspartyl/asparaginyl beta-hydroxylase', 'EC 1.14.11.16', 'Aspartate beta-hydroxylase', 'ASP beta-hydroxylase', 'Peptide-aspartate beta-dioxygenase']}
# Q12797|aspartyl/asparaginyl_beta-hydroxylase|ec_1.14.11.16|aspartate_beta-hydroxylase|asp_beta-hydroxylase|peptide-aspartate_beta-dioxygenase
# -------------------------
# {'ID': 'Q01484', 'names': ['Ankyrin-2', 'ANK-2', 'Ankyrin-B', 'Brain ankyrin', 'Non-erythroid ankyrin']}
# Q01484|ankyrin-2|ank-2|ankyrin-b|brain_ankyrin|non-erythroid_ankyrin
# -------------------------
# {'ID': 'Q03135', 'names': ['Caveolin-1', 'Ankyrin-B', 'Brain ankyrin', 'Non-erythroid ankyrin']}
# Q03135|caveolin-1|ankyrin-b|brain_ankyrin|non-erythroid_ankyrin
# -------------------------
# {'ID': 'P0DP23', 'names': ['Calmodulin-1', 'Ankyrin-B', 'Brain ankyrin', 'Non-erythroid ankyrin']}
# P0DP23|calmodulin-1|ankyrin-b|brain_ankyrin|non-erythroid_ankyrin
# -------------------------
# {'ID': 'O14958', 'names': ['Calsequestrin-2', 'Calsequestrin, cardiac muscle isoform']}
# O14958|calsequestrin-2|calsequestrin,_cardiac_muscle_isoform
# -------------------------
# {'ID': 'P16615', 'names': ['Sarcoplasmic/endoplasmic reticulum calcium ATPase 2', 'SERCA2', 'SR Ca(2+)-ATPase 2', 'EC 7.2.2.10', 'Calcium pump 2', 'Calcium-transporting ATPase sarcoplasmic reticulum type, slow twitch skeletal muscle isoform', 'Endoplasmic reticulum class 1/2 Ca(2+) ATPase']}
# P16615|sarcoplasmic/endoplasmic_reticulum_calcium_atpase_2|serca2|sr_ca(2+)-atpase_2|ec_7.2.2.10|calcium_pump_2|calcium-transporting_atpase_sarcoplasmic_reticulum_type,_slow_twitch_skeletal_muscle_isoform|endoplasmic_reticulum_class_1/2_ca(2+)_atpase
# -------------------------
# {'ID': 'P56539', 'names': ['Caveolin-3', 'M-caveolin']}
# P56539|caveolin-3|m-caveolin
# -------------------------
# {'ID': 'Q99828', 'names': ['Calcium and integrin-binding protein 1', 'CIB', 'Calcium- and integrin-binding protein', 'CIBP', 'Calmyrin', 'DNA-PKcs-interacting protein', 'Kinase-interacting protein', 'KIP', 'SNK-interacting protein 2-28', 'SIP2-28']}
# Q99828|calcium_and_integrin-binding_protein_1|cib|calcium-_and_integrin-binding_protein|cibp|calmyrin|dna-pkcs-interacting_protein|kinase-interacting_protein|kip|snk-interacting_protein_2-28|sip2-28
# -------------------------
# {'ID': 'Q13023', 'names': ['A-kinase anchor protein 6', 'AKAP-6', 'A-kinase anchor protein 100 kDa', 'AKAP 100', 'Protein kinase A-anchoring protein 6', 'PRKA6', 'mAKAP']}
# Q13023|a-kinase_anchor_protein_6|akap-6|a-kinase_anchor_protein_100_kda|akap_100|protein_kinase_a-anchoring_protein_6|prka6|makap
# -------------------------
# {'ID': 'P11021', 'names': ['Endoplasmic reticulum chaperone BiP', 'EC 3.6.4.10', '78 kDa glucose-regulated protein', 'GRP-78', 'Binding-immunoglobulin protein', 'BiP', 'Heat shock protein 70 family protein 5', 'HSP70 family protein 5', 'Heat shock protein family A member 5', 'Immunoglobulin heavy chain-binding protein']}
# P11021|endoplasmic_reticulum_chaperone_bip|ec_3.6.4.10|78_kda_glucose-regulated_protein|grp-78|binding-immunoglobulin_protein|bip|heat_shock_protein_70_family_protein_5|hsp70_family_protein_5|heat_shock_protein_family_a_member_5|immunoglobulin_heavy_chain-binding_protein
# -------------------------
# {'ID': 'P05067', 'names': ['Amyloid-beta precursor protein', 'APP', 'ABPP', 'APPI', 'Alzheimer disease amyloid protein', 'Amyloid precursor protein', 'Amyloid-beta A4 protein', 'Cerebral vascular amyloid peptide', 'CVAP', 'PreA4', 'Protease nexin-II', 'PN-II']}
# P05067|amyloid-beta_precursor_protein|app|abpp|appi|alzheimer_disease_amyloid_protein|amyloid_precursor_protein|amyloid-beta_a4_protein|cerebral_vascular_amyloid_peptide|cvap|prea4|protease_nexin-ii|pn-ii
# -------------------------
# {'ID': 'P20073', 'names': ['Annexin A7', 'Annexin VII', 'Annexin-7', 'Synexin']}
# P20073|annexin_a7|annexin_vii|annexin-7|synexin
# -------------------------
# {'ID': 'Q9BXT2', 'names': ['Voltage-dependent calcium channel gamma-6 subunit', 'Neuronal voltage-gated calcium channel gamma-6 subunit']}
# Q9BXT2|voltage-dependent_calcium_channel_gamma-6_subunit|neuronal_voltage-gated_calcium_channel_gamma-6_subunit
# -------------------------
# {'ID': 'P23634', 'names': ['Plasma membrane calcium-transporting ATPase 4', 'PMCA4', 'EC 7.2.2.10', 'Matrix-remodeling-associated protein 1', 'Plasma membrane calcium ATPase isoform 4', 'Plasma membrane calcium pump isoform 4']}
# P23634|plasma_membrane_calcium-transporting_atpase_4|pmca4|ec_7.2.2.10|matrix-remodeling-associated_protein_1|plasma_membrane_calcium_atpase_isoform_4|plasma_membrane_calcium_pump_isoform_4
# -------------------------
# {'ID': 'P35609', 'names': ['Alpha-actinin-2', 'Alpha-actinin skeletal muscle isoform 2', 'F-actin cross-linking protein']}
# P35609|alpha-actinin-2|alpha-actinin_skeletal_muscle_isoform_2|f-actin_cross-linking_protein
# -------------------------
# {'ID': 'Q9ULB1', 'names': ['Neurexin-1', 'Neurexin I-alpha', 'Neurexin-1-alpha']}
# Q9ULB1|neurexin-1|neurexin_i-alpha|neurexin-1-alpha
# -------------------------
# {'ID': 'Q9HDC5', 'names': ['Junctophilin-1', 'JP-1', 'Junctophilin type 1']}
# Q9HDC5|junctophilin-1|jp-1|junctophilin_type_1
# -------------------------
# {'ID': 'Q86UT5', 'names': ['Na(+)/H(+) exchange regulatory cofactor NHE-RF4', 'NHERF-4', 'Intestinal and kidney-enriched PDZ protein', 'Natrium-phosphate cotransporter IIa C-terminal-associated protein 2', 'Na/Pi cotransporter C-terminal-associated protein 2', 'NaPi-Cap2', 'PDZ domain-containing protein 2', 'PDZ domain-containing protein 3', 'Sodium-hydrogen exchanger regulatory factor 4']}
# Q86UT5|na(+)/h(+)_exchange_regulatory_cofactor_nhe-rf4|nherf-4|intestinal_and_kidney-enriched_pdz_protein|natrium-phosphate_cotransporter_iia_c-terminal-associated_protein_2|na/pi_cotransporter_c-terminal-associated_protein_2|napi-cap2|pdz_domain-containing_protein_2|pdz_domain-containing_protein_3|sodium-hydrogen_exchanger_regulatory_factor_4
# -------------------------
# {'ID': 'Q9NZN3', 'names': ['EH domain-containing protein 3', 'PAST homolog 3']}
# Q9NZN3|eh_domain-containing_protein_3|past_homolog_3
# -------------------------
# {'ID': 'Q13557', 'names': ['Calcium/calmodulin-dependent protein kinase type II subunit delta', 'CaM kinase II subunit delta', 'CaMK-II subunit delta', 'EC 2.7.11.17', 'PAST homolog 3']}
# Q13557|calcium/calmodulin-dependent_protein_kinase_type_ii_subunit_delta|cam_kinase_ii_subunit_delta|camk-ii_subunit_delta|ec_2.7.11.17|past_homolog_3
# -------------------------
# {'ID': 'Q14957', 'names': ['Glutamate receptor ionotropic, NMDA 2C', 'GluN2C', 'Glutamate [NMDA] receptor subunit epsilon-3', 'N-methyl D-aspartate receptor subtype 2C', 'NMDAR2C', 'NR2C']}
# Q14957|glutamate_receptor_ionotropic,_nmda_2c|glun2c|glutamate_[nmda]_receptor_subunit_epsilon-3|n-methyl_d-aspartate_receptor_subtype_2c|nmdar2c|nr2c
# -------------------------
# {'ID': 'Q8NE86', 'names': ['Calcium uniporter protein, mitochondrial', 'HsMCU', 'Coiled-coil domain-containing protein 109A']}
# Q8NE86|calcium_uniporter_protein,_mitochondrial|hsmcu|coiled-coil_domain-containing_protein_109a
# -------------------------
# {'ID': 'Q9BR39', 'names': ['Junctophilin-2', 'JP-2', 'Junctophilin type 2']}
# Q9BR39|junctophilin-2|jp-2|junctophilin_type_2
# -------------------------
# {'ID': 'P98161', 'names': ['Polycystin-1', 'PC1', 'Autosomal dominant polycystic kidney disease 1 protein']}
# P98161|polycystin-1|pc1|autosomal_dominant_polycystic_kidney_disease_1_protein
# -------------------------
# {'ID': 'P17252', 'names': ['Protein kinase C alpha type', 'PKC-A', 'PKC-alpha', 'EC 2.7.11.13', 'Autosomal dominant polycystic kidney disease 1 protein']}
# P17252|protein_kinase_c_alpha_type|pkc-a|pkc-alpha|ec_2.7.11.13|autosomal_dominant_polycystic_kidney_disease_1_protein
# -------------------------
# {'ID': 'P14416', 'names': ['D(2) dopamine receptor', 'Dopamine D2 receptor']}
# P14416|d(2)_dopamine_receptor|dopamine_d2_receptor
# -------------------------
# {'ID': 'Q96D31', 'names': ['Calcium release-activated calcium channel protein 1', 'Protein orai-1', 'Transmembrane protein 142A']}
# Q96D31|calcium_release-activated_calcium_channel_protein_1|protein_orai-1|transmembrane_protein_142a
# -------------------------
# {'ID': 'Q6J4K2', 'names': ['Mitochondrial sodium/calcium exchanger protein', 'Na(+)/K(+)/Ca(2+)-exchange protein 6', 'Sodium/calcium exchanger protein, mitochondrial', 'Sodium/potassium/calcium exchanger 6', 'Solute carrier family 24 member 6', 'Solute carrier family 8 member B1']}
# Q6J4K2|mitochondrial_sodium/calcium_exchanger_protein|na(+)/k(+)/ca(2+)-exchange_protein_6|sodium/calcium_exchanger_protein,_mitochondrial|sodium/potassium/calcium_exchanger_6|solute_carrier_family_24_member_6|solute_carrier_family_8_member_b1
# -------------------------
# {'ID': 'O00141', 'names': ['Serine/threonine-protein kinase Sgk1', 'EC 2.7.11.1', 'Serum/glucocorticoid-regulated kinase 1']}
# O00141|serine/threonine-protein_kinase_sgk1|ec_2.7.11.1|serum/glucocorticoid-regulated_kinase_1
# -------------------------
# {'ID': 'Q13586', 'names': ['Stromal interaction molecule 1', 'Serum/glucocorticoid-regulated kinase 1']}
# Q13586|stromal_interaction_molecule_1|serum/glucocorticoid-regulated_kinase_1
# -------------------------
# {'ID': 'Q14643', 'names': ['Inositol 1,4,5-trisphosphate receptor type 1', 'IP3 receptor isoform 1', 'IP3R 1', 'InsP3R1', 'Type 1 inositol 1,4,5-trisphosphate receptor', 'Type 1 InsP3 receptor']}
# Q14643|inositol_1,4,5-trisphosphate_receptor_type_1|ip3_receptor_isoform_1|ip3r_1|insp3r1|type_1_inositol_1,4,5-trisphosphate_receptor|type_1_insp3_receptor
# -------------------------
# {'ID': 'Q14573', 'names': ['Inositol 1,4,5-trisphosphate receptor type 3', 'IP3 receptor isoform 3', 'IP3R 3', 'InsP3R3', 'Type 3 inositol 1,4,5-trisphosphate receptor', 'Type 3 InsP3 receptor']}
# Q14573|inositol_1,4,5-trisphosphate_receptor_type_3|ip3_receptor_isoform_3|ip3r_3|insp3r3|type_3_inositol_1,4,5-trisphosphate_receptor|type_3_insp3_receptor
# -------------------------
# {'ID': 'Q9BPX6', 'names': ['Calcium uptake protein 1, mitochondrial', 'Atopy-related autoantigen CALC', 'ara CALC', 'Calcium-binding atopy-related autoantigen 1']}
# Q9BPX6|calcium_uptake_protein_1,_mitochondrial|atopy-related_autoantigen_calc|ara_calc|calcium-binding_atopy-related_autoantigen_1
# -------------------------
# {'ID': 'Q02790', 'names': ['Peptidyl-prolyl cis-trans isomerase FKBP4', 'PPIase FKBP4', 'EC 5.2.1.8', '51 kDa FK506-binding protein', 'FKBP51', '52 kDa FK506-binding protein', '52 kDa FKBP', 'FKBP-52', '59 kDa immunophilin', 'p59', 'FK506-binding protein 4', 'FKBP-4', 'FKBP59', 'HSP-binding immunophilin', 'HBI', 'Immunophilin FKBP52', 'Rotamase']}
# Q02790|peptidyl-prolyl_cis-trans_isomerase_fkbp4|ppiase_fkbp4|ec_5.2.1.8|51_kda_fk506-binding_protein|fkbp51|52_kda_fk506-binding_protein|52_kda_fkbp|fkbp-52|59_kda_immunophilin|p59|fk506-binding_protein_4|fkbp-4|fkbp59|hsp-binding_immunophilin|hbi|immunophilin_fkbp52|rotamase
# -------------------------
# {'ID': 'P14780', 'names': ['Matrix metalloproteinase-9', 'MMP-9', 'EC 3.4.24.35', '92 kDa gelatinase', '92 kDa type IV collagenase', 'Gelatinase B', 'GELB']}
# P14780|matrix_metalloproteinase-9|mmp-9|ec_3.4.24.35|92_kda_gelatinase|92_kda_type_iv_collagenase|gelatinase_b|gelb
# -------------------------
# {'ID': 'P49281', 'names': ['Natural resistance-associated macrophage protein 2', 'NRAMP 2', 'Divalent cation transporter 1', 'Divalent metal transporter 1', 'DMT-1', 'Solute carrier family 11 member 2']}
# P49281|natural_resistance-associated_macrophage_protein_2|nramp_2|divalent_cation_transporter_1|divalent_metal_transporter_1|dmt-1|solute_carrier_family_11_member_2
# -------------------------
# {'ID': 'Q5S007', 'names': ['Leucine-rich repeat serine/threonine-protein kinase 2', 'EC 2.7.11.1', 'EC 3.6.5.-', 'Dardarin']}
# Q5S007|leucine-rich_repeat_serine/threonine-protein_kinase_2|ec_2.7.11.1|ec_3.6.5.-|dardarin
# -------------------------
# {'ID': 'S4R468', 'names': ['Calcium uniporter protein', 'Dardarin']}
# S4R468|calcium_uniporter_protein|dardarin
# -------------------------
# {'ID': 'B4DWD0', 'names': ['Calcium uniporter protein', 'Dardarin']}
# B4DWD0|calcium_uniporter_protein|dardarin
# -------------------------
